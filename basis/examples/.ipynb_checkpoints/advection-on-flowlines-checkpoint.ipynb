# %%
import numpy as np
import matplotlib.pyplot as plt

from netCDF4 import Dataset
import rasterio as rio

from landlab.grid.raster_funcs import find_nearest_node
from landlab.io.netcdf import read_netcdf
from landlab import RasterModelGrid
from landlab.plot import imshow_grid

from scipy.signal import spline_filter

# %%
h_file = '/home/egp/repos/alpine-case-studies/mendenhall/gis/inputs/mendenhall_ice_h.tif'
vx_file = '/home/egp/repos/alpine-case-studies/mendenhall/gis/inputs/test_stateplane_crs.tif'
vy_file = '/home/egp/repos/alpine-case-studies/mendenhall/gis/inputs/mendenhall_vy.tif'

# %% [raw]
# h_data.renameVariable('Band1', 'ice_thickness')
# vx_data.renameVariable('Band1', 'velocity_x')
# vy_data.renameVariable('Band1', 'velocity_y')

# %%
with rio.open(h_file) as fh:
    h_data = fh.read(1)
    lower_left = (fh.bounds.left, fh.bounds.bottom)
    resolution = fh.res
    
with rio.open(vy_file) as fy:
    vy_data = fy.read(1)

with rio.open(vx_file) as fx:
    vx_data = fx.read(1)

# %%
grid = RasterModelGrid(vx_data.shape, xy_of_lower_left = lower_left, xy_spacing = resolution)
vy = grid.add_field('velocity_y', vx_data, at = 'node')
imshow_grid(grid, vy)

# %%
grid = RasterModelGrid(h_data.shape)
h = grid.add_field('ice_thickness', h_data, at = 'node')
vx = grid.add_field('velocity_x', vy_data, at = 'node')
vy = grid.add_field('velocity_y', vx_data, at = 'node')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [20], in <cell line: 4>()
#       2 h = grid.add_field('ice_thickness', h_data, at = 'node')
#       3 vx = grid.add_field('velocity_x', vy_data, at = 'node')
# ----> 4 vy = grid.add_field('velocity_y', vx_data, at = 'node')
#
# File ~/dev/anaconda3/envs/basis/lib/python3.10/site-packages/landlab/field/graph_field.py:1119, in GraphFields.add_field(self, *args, **kwds)
#    1116     dims += (name + "_per_" + at,)
#    1117     value_array = value_array.reshape((value_array.shape[0], -1))
# -> 1119 ds.set_value(name, value_array, attrs=attrs)
#    1120 # ds[name] = value_array
#    1121 return ds[name]
#
# File ~/dev/anaconda3/envs/basis/lib/python3.10/site-packages/landlab/field/graph_field.py:287, in FieldDataset.set_value(self, name, value_array, attrs)
#     284     return
#     286 if self.fixed_size:
# --> 287     value_array = reshape_for_storage(value_array, self.size)
#     288 else:
#     289     value_array = reshape_for_storage(value_array, None)
#
# File ~/dev/anaconda3/envs/basis/lib/python3.10/site-packages/landlab/field/graph_field.py:50, in reshape_for_storage(array, field_size)
#       7 def reshape_for_storage(array, field_size=None):
#       8     """Reshape an array to be stored as a field.
#       9
#      10     For reshaping rules, see ``shape_for_storage``.
#    (...)
#      48     :meta private:
#      49     """
# ---> 50     shape = shape_for_storage(array, field_size)
#      51     if shape == array.shape or array.ndim == 0:
#      52         return array
#
# File ~/dev/anaconda3/envs/basis/lib/python3.10/site-packages/landlab/field/graph_field.py:129, in shape_for_storage(array, field_size)
#     126     field_size = array.size
#     128 if array.size % field_size != 0:
# --> 129     raise ValueError(
#     130         "unable to reshape array to field size ({0} != {1})".format(
#     131             array.size, field_size
#     132         )
#     133     )
#     135 if field_size == array.size:
#     136     shape = (array.size,)
#
# ValueError: unable to reshape array to field size (94135 != 90475)

# %%
imshow_grid(grid, vx)

# %%
with rio.open(h_file) as fh:
    h_data = np.flip(fh.read(1), axis = 0)

with rio.open(vy_file) as fy:
    vy_data = np.flip(-fy.read(1), axis = 0)

with rio.open(vx_file) as fx:
    vx_data = np.flip(fx.read(1), axis = 0)

# %%
grid = RasterModelGrid((329, 275))

# %%
# vx and vy are intentionally swapped
h = grid.add_field('ice_h', h_data, at = 'node', copy = True, clobber = True, nodata_value = -99999)
vx = grid.add_field('velocity_x', vy_data, at = 'node', copy = True, clobber = True)
vy = grid.add_field('velocity_y', vx_data, at = 'node', copy = True, clobber = True)
vv = grid.add_field('velocity', np.sqrt(vx**2 + vy**2), at = 'node', clobber = True)

# %%
imshow_grid(grid, vx)

# %%
starting_region = np.where(vv > 120)[0]
n_pts = 100
sample = np.random.choice(starting_region, size = n_pts, replace = False)

imshow_grid(grid, h)
for i in sample:
    x = grid.node_x[i]
    y = grid.node_y[i]
    plt.scatter(x, y, s = 5)
plt.show()

# %%
nt = 7000
flowline = {'time_step': np.array([t for t in range(nt)]),
            'velocity': np.empty(nt),
            'ice_h': np.empty(nt),
            'nodes': np.empty(nt),
            'distance': np.empty(nt)}

node_id = np.random.choice(starting_region, size = 1)
x_loc = grid.node_x[node_id]
y_loc = grid.node_y[node_id]

o_x = grid.node_x[node_id]
o_y = grid.node_y[node_id]

dt = 0.025
scale = 1 / 50
y_break = 10

for t in range(nt):
    flowline['velocity'][t] = vv[node_id]
    flowline['ice_h'][t] = h[node_id]
    flowline['nodes'][t] = node_id
    flowline['distance'][t] = np.sqrt((x_loc - o_x)**2 + (y_loc - o_y)**2)
    
    x_loc += vx[node_id] * scale * dt
    y_loc += vy[node_id] * scale * dt
    
    node_id = find_nearest_node(grid, (x_loc, y_loc))
    
    if y_loc < y_break:
        break

# %%
imshow_grid(grid, h)
for i in range(len(flowline['nodes'])):
    idx = int(flowline['nodes'][i])
    
    if i % 100 == 0:
        plt.scatter(grid.node_x[idx], grid.node_y[idx], s = 5)
        
plt.show()

# %%
fig, ax = plt.subplots(figsize = (10, 2))

plt.scatter(flowline['distance'] * 50, flowline['ice_h'], s = 1)
plt.show()
