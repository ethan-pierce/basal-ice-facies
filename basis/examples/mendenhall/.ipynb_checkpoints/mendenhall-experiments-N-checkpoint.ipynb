# %%
import numpy as np
import matplotlib.pyplot as plt
import rasterio as rio

from landlab import RasterModelGrid
from landlab.plot import imshow_grid

import sys
sys.path.append('/home/egp/repos/basal-ice-facies/basis/src/')
from src.basal_ice_stratigrapher import BasalIceStratigrapher

# %% [markdown]
# ### Start: effective pressure = 0.05 * P$_i$

# %%
N_scales = [0.05, 0.1, 0.2, 0.4]
models = {i: BasalIceStratigrapher('inputs/input_file.toml') for i in range(len(N_scales))}

with rio.open('./inputs/ice_thickness.tif', 'r') as f:
    data = np.flip(f.read(1), axis = 0)
    
    for key, model in models.items():
        model.grid.add_field('glacier__thickness', data, at = 'node', clobber = True)
        model.grid.add_field('glacier__effective_pressure', 
                             model.grid.at_node['glacier__thickness'][:] * 917 * 9.81 * N_scales[key], 
                             at = 'node', clobber = True)

with rio.open('./inputs/surface_velocity_x.tif', 'r') as f:
    data = -1 * np.flip(f.read(1), axis = 0) * 0.6
    
    for key, model in models.items():
        model.grid.add_field('glacier__sliding_velocity_x', data, at = 'node', clobber = True)
    
with rio.open('./inputs/surface_velocity_y.tif', 'r') as f:
    data = np.flip(f.read(1), axis = 0) * 0.6
    
    for key, model in models.items():
        model.grid.add_field('glacier__sliding_velocity_y', data, at = 'node', clobber = True)

for key, model in models.items():
    model.grid.add_field('glacier__sliding_velocity', 
                         np.sqrt(model.grid.at_node['glacier__sliding_velocity_x'][:]**2 + model.grid.at_node['glacier__sliding_velocity_y'][:]**2), 
                         at = 'node', clobber = True)

# %%
fig, ax = plt.subplots(1, 4, figsize = (30, 6))

for key, model in models.items():
    
    im = ax[key].imshow(np.flip(np.reshape(model.grid.at_node['glacier__effective_pressure'][:] * 1e-3, model.grid.shape), axis = 0),
                   cmap = 'pink')
    plt.colorbar(im, ax = ax[key])
    ax[key].set_title('N = ' + str(N_scales[key]) + ' * P$_i$ (kPa)')
    
    
plt.show()

# %%
for key, model in models.items():
    model.run_one_step(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
#       1 for key, model in models.items():
# ----> 2     model.run_one_step(1)
#
# File ~/repos/basal-ice-facies/basis/src/basal_ice_stratigrapher.py:301, in BasalIceStratigrapher.run_one_step(self, dt)
#     299 self.calc_fringe_growth_rate()
#     300 self.calc_regelation_rate()
# --> 301 self.calc_advection()
#     303 expected_fringe_growth = self.grid.at_node['fringe__growth_rate'][:] * dt
#     305 self.grid.at_node['frozen_fringe__thickness'][:] = np.where(
#     306     expected_fringe_growth <= self.grid.at_node['soil__depth'][:],
#     307     self.grid.at_node['frozen_fringe__thickness'][:] + expected_fringe_growth,
#     308     self.grid.at_node['frozen_fringe__thickness'][:] + self.grid.at_node['soil__depth'][:]
#     309 )
#
# File ~/repos/basal-ice-facies/basis/src/basal_ice_stratigrapher.py:281, in BasalIceStratigrapher.calc_advection(self)
#     279 hf = self.grid.at_node['frozen_fringe__thickness'][:]
#     280 grad_hf = self.grid.calc_grad_at_link(hf)
# --> 281 fringe_advection = self.grid.map_mean_of_links_to_node(ub_links * grad_hf)
#     282 fringe_deformation = hf * div_u
#     283 self.grid.at_node['fringe__growth_rate'][:] -= (fringe_advection + fringe_deformation)
#
# NameError: name 'ub_links' is not defined
